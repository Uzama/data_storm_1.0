# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder

# %%
test_data = pd.read_csv('../../req_data/credit_card_default_test.csv')
train_data = pd.read_csv('../../req_data/credit_card_default_train.csv')

# %%
sns.heatmap(train_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
train_data.head()
# Out:
#   Client_ID Balance_Limit_V1 Gender EDUCATION_STATUS MARITAL_STATUS  \
# 0        A2               1M      M         Graduate          Other
# 1        A3               1M      F      High School          Other
# 2        A4             100K      F      High School         Single
# 3        A5             200K      F         Graduate         Single
# 4        A6               1M      F         Graduate          Other
# 5        A8             400K      F         Graduate         Single
# 6        A9             100K      M            Other         Single
# 7       A11             100K      F      High School          Other
# 8       A12             500K      M            Other          Other
# 9       A13               1M      M            Other         Single
#
#             AGE  PAY_JULY  PAY_AUG  PAY_SEP  PAY_OCT         ...          \
# 0         31-45        -1       -1       -1       -1         ...
# 1  Less than 30         0       -1       -1       -1         ...
# 2         31-45         4        3        2        2         ...
# 3         31-45         2        0        0        0         ...
# 4         31-45         2        2        0        0         ...
# 5         31-45         0        0        0        0         ...
# 6  Less than 30         1        2        2        2         ...
# 7  Less than 30         2        2        2        0         ...
# 8         31-45         0        0        0        2         ...
# 9         46-65         0        0        2        0         ...
#
#    DUE_AMT_OCT  DUE_AMT_NOV  DUE_AMT_DEC  PAID_AMT_JULY  PAID_AMT_AUG  \
# 0        39418       162772       -13982           3437          6004
# 1        43530        80811       124590         151818         46200
# 2            0            0            0              0             0
# 3        97309       100353       102740           3855          3890
# 4       435354       445271       453899              0         20790
# 5       353910       356117       358845          16632         18480
# 6        11173        12030        12647              0          3696
# 7        55325        59272        57976           5521             0
# 8       212970       213654       217992           9240         17325
# 9       221148       222936       224276          26565             0
#
#    PAID_AMT_SEP  PAID_AMT_OCT  PAID_AMT_NOV  PAID_AMT_DEC  NEXT_MONTH_DEFAULT
# 0         39418        162772             0        538165                   0
# 1         43530         80811           942         33666                   0
# 2             0             0             0             0                   1
# 3          3696          4620          4049          3918                   1
# 4         16170         17325         16401         17325                   0
# 5         12728         13398         13860         12705                   0
# 6             0          1386          1155             0                   0
# 7          1984          4844             0          2523                   1
# 8             0          6930         11550         11550                   0
# 9          8184          8547          8194          7311                   0
#
# [10 rows x 25 columns]

# %%
sns.set_style('whitegrid')
sns.countplot(x='NEXT_MONTH_DEFAULT',hue='EDUCATION_STATUS',data=train_data,palette='RdBu_r')

# %%
train_data[['EDUCATION_STATUS', 'NEXT_MONTH_DEFAULT']].groupby(['EDUCATION_STATUS'], as_index=False).mean().sort_values(by='NEXT_MONTH_DEFAULT', ascending=False)
# Out:
#   EDUCATION_STATUS  NEXT_MONTH_DEFAULT
# 1      High School            0.251210
# 2            Other            0.232301
# 0         Graduate            0.194621

# %%
sns.set_style('whitegrid')
sns.countplot(x='NEXT_MONTH_DEFAULT',hue='EDUCATION_STATUS',data=train_data,palette='RdBu_r')

# %%
def my_fun(x):
    if (x[-1]=='K'):
        x=x[:-1]
    else:
        x= float(x[:-1])*1000
    return x

# %%
train_data['Balance_Limit_V1']=train_data['Balance_Limit_V1'].apply(lambda x: my_fun(x))

# %%
train_data.head()
# Out:
#   Client_ID Balance_Limit_V1 Gender EDUCATION_STATUS MARITAL_STATUS  \
# 0        A2             1000      M         Graduate          Other
# 1        A3             1000      F      High School          Other
# 2        A4              100      F      High School         Single
# 3        A5              200      F         Graduate         Single
# 4        A6             1000      F         Graduate          Other
#
#             AGE  PAY_JULY  PAY_AUG  PAY_SEP  PAY_OCT         ...          \
# 0         31-45        -1       -1       -1       -1         ...
# 1  Less than 30         0       -1       -1       -1         ...
# 2         31-45         4        3        2        2         ...
# 3         31-45         2        0        0        0         ...
# 4         31-45         2        2        0        0         ...
#
#    DUE_AMT_OCT  DUE_AMT_NOV  DUE_AMT_DEC  PAID_AMT_JULY  PAID_AMT_AUG  \
# 0        39418       162772       -13982           3437          6004
# 1        43530        80811       124590         151818         46200
# 2            0            0            0              0             0
# 3        97309       100353       102740           3855          3890
# 4       435354       445271       453899              0         20790
#
#    PAID_AMT_SEP  PAID_AMT_OCT  PAID_AMT_NOV  PAID_AMT_DEC  NEXT_MONTH_DEFAULT
# 0         39418        162772             0        538165                   0
# 1         43530         80811           942         33666                   0
# 2             0             0             0             0                   1
# 3          3696          4620          4049          3918                   1
# 4         16170         17325         16401         17325                   0
#
# [5 rows x 25 columns]

# %%
encoder= LabelEncoder()
train_data['Gender']=encoder.fit_transform(train_data['Gender'])
train_data['EDUCATION_STATUS']=encoder.fit_transform(train_data['EDUCATION_STATUS'])
train_data['MARITAL_STATUS']=encoder.fit_transform(train_data['MARITAL_STATUS'])
train_data['AGE']=encoder.fit_transform(train_data['AGE'])

# %%
train_data.head(20)
# Out:
#    Client_ID Balance_Limit_V1  Gender  EDUCATION_STATUS  MARITAL_STATUS  AGE  \
# 0         A2             1000       1                 0               0    0
# 1         A3             1000       0                 1               0    2
# 2         A4              100       0                 1               1    0
# 3         A5              200       0                 0               1    0
# 4         A6             1000       0                 0               0    0
# 5         A8              400       0                 0               1    0
# 6         A9              100       1                 2               1    2
# 7        A11              100       0                 1               0    2
# 8        A12              500       1                 2               0    0
# 9        A13             1000       1                 2               1    1
# 10       A15              500       1                 0               0    2
# 11       A16              500       0                 0               0    0
# 12       A17             1000       0                 0               1    0
# 13       A18              100       0                 0               0    2
# 14       A19              100       0                 1               0    0
# 15       A21              400       1                 1               0    1
# 16       A22              100       0                 1               1    0
# 17       A24              100       1                 2               0    2
# 18       A27              100       0                 2               1    1
# 19       A29              200       1                 2               1    0
#
#     PAY_JULY  PAY_AUG  PAY_SEP  PAY_OCT         ...          DUE_AMT_OCT  \
# 0         -1       -1       -1       -1         ...                39418
# 1          0       -1       -1       -1         ...                43530
# 2          4        3        2        2         ...                    0
# 3          2        0        0        0         ...                97309
# 4          2        2        0        0         ...               435354
# 5          0        0        0        0         ...               353910
# 6          1        2        2        2         ...                11173
# 7          2        2        2        0         ...                55325
# 8          0        0        0        2         ...               212970
# 9          0        0        2        0         ...               221148
# 10        -2       -2       -2       -2         ...                 1855
# 11        -1       -1       -1       -1         ...                34888
# 12        -2       -2       -1        0         ...                81388
# 13         0        0        0        0         ...                43890
# 14         0        0        0       -2         ...                    0
# 15         2        0        0        0         ...               147265
# 16         2        2        2        0         ...                52486
# 17         0        0        0        0         ...                26847
# 18        -2       -2       -2       -2         ...                    0
# 19         0        0        0        0         ...               124786
#
#     DUE_AMT_NOV  DUE_AMT_DEC  PAID_AMT_JULY  PAID_AMT_AUG  PAID_AMT_SEP  \
# 0        162772       -13982           3437          6004         39418
# 1         80811       124590         151818         46200         43530
# 2             0            0              0             0             0
# 3        100353       102740           3855          3890          3696
# 4        445271       453899              0         20790         16170
# 5        356117       358845          16632         18480         12728
# 6         12030        12647              0          3696             0
# 7         59272        57976           5521             0          1984
# 8        213654       217992           9240         17325             0
# 9        222936       224276          26565             0          8184
# 10         2116         2747           2617          1321          1855
# 11        32522        48228          56191         93012         35017
# 12         2042        22924           2174        103356             0
# 13        44807        46064           3003          3721          1617
# 14            0            0           4084             0             0
# 15       151123       157242           6930          4620          4620
# 16        54056        57750          10395             0          3465
# 17        30677        29517           3049          5038          2079
# 18            0            0              0             0             0
# 19       129018       102301           6930          5775          4620
#
#     PAID_AMT_OCT  PAID_AMT_NOV  PAID_AMT_DEC  NEXT_MONTH_DEFAULT
# 0         162772             0        538165                   0
# 1          80811           942         33666                   0
# 2              0             0             0                   1
# 3           4620          4049          3918                   1
# 4          17325         16401         17325                   0
# 5          13398         13860         12705                   0
# 6           1386          1155             0                   0
# 7           4844             0          2523                   1
# 8           6930         11550         11550                   0
# 9           8547          8194          7311                   0
# 10          2116          2747           866                   0
# 11         32522         48228         61714                   0
# 12          2042         22924         25003                   1
# 13          1626          2003          1379                   0
# 14             0             0             0                   1
# 15          4620          6930          6930                   1
# 16          2772          4620          6930                   1
# 17          4620             0             0                   0
# 18             0             0         44835                   0
# 19          6930          4620          3465                   0
#
# [20 rows x 25 columns]

# %% [markdown]
# Splitting Data

# %%
X_train = train_data.drop(['Client_ID','NEXT_MONTH_DEFAULT'], axis=1)
y_train = train_data['NEXT_MONTH_DEFAULT']
X_test = test_data.drop(['Client_ID'], axis=1)

# %% [markdown]
# Using Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
predictions = dtree.predict(X_test)

# %% [markdown]
# Using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100)
rfc.fit(X_train, y_train)

# %%
rfc_pred = rfc.predict(X_test)
